# %%
# %cd /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort
# Out:
# /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort

# %%
# !git clone https://github.com/ZQPei/deep_sort_pytorch.git
# Out:
# Cloning into 'deep_sort_pytorch'...
# remote: Enumerating objects: 726, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 726 (delta 4), reused 1 (delta 0), pack-reused 717
# Receiving objects: 100% (726/726), 23.72 MiB | 16.22 MiB/s, done.
# Resolving deltas: 100% (351/351), done.

# %%
# %cd deep_sort_pytorch/
# Out:
# /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort/deep_sort_pytorch

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting atomicwrites==1.3.0 (from -r requirements.txt (line 1))
#   Downloading atomicwrites-1.3.0-py2.py3-none-any.whl (5.9 kB)
# Collecting attrs==19.3.0 (from -r requirements.txt (line 2))
#   Downloading attrs-19.3.0-py2.py3-none-any.whl (39 kB)
# Collecting colorama==0.4.3 (from -r requirements.txt (line 3))
#   Downloading colorama-0.4.3-py2.py3-none-any.whl (15 kB)
# Collecting easydict==1.9 (from -r requirements.txt (line 4))
#   Downloading easydict-1.9.tar.gz (6.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting entrypoints==0.3 (from -r requirements.txt (line 5))
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting et-xmlfile==1.0.1 (from -r requirements.txt (line 6))
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting flake8==3.7.9 (from -r requirements.txt (line 7))
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 9.4 MB/s eta 0:00:00
# Collecting flake8-import-order==0.18.1 (from -r requirements.txt (line 8))
#   Downloading flake8_import_order-0.18.1-py2.py3-none-any.whl (15 kB)
# Collecting importlib-metadata==1.6.0 (from -r requirements.txt (line 9))
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting jdcal==1.4.1 (from -r requirements.txt (line 10))
#   Downloading jdcal-1.4.1-py2.py3-none-any.whl (9.5 kB)
# Collecting joblib==0.14.1 (from -r requirements.txt (line 11))
#   Downloading joblib-0.14.1-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 16.7 MB/s eta 0:00:00
# Collecting numpy==1.18.2 (from -r requirements.txt (line 12))
#   Downloading numpy-1.18.2.zip (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 72.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lap==0.4.0 (from -r requirements.txt (line 13))
#   Downloading lap-0.4.0.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 83.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting mccabe==0.6.1 (from -r requirements.txt (line 14))
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting more-itertools==8.2.0 (from -r requirements.txt (line 15))
#   Downloading more_itertools-8.2.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 5.6 MB/s eta 0:00:00
# Collecting motmetrics==1.2.0 (from -r requirements.txt (line 16))
#   Downloading motmetrics-1.2.0-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.6/151.6 kB 19.5 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.2.0.34 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72)
# ERROR: No matching distribution found for opencv-python==4.2.0.34

# %%
pwd
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort/deep_sort_pytorch/deep_sort/deep
# Out:
# /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort/deep_sort_pytorch/deep_sort/deep

# %%
# %cp -r /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort/data /content/drive/MyDrive/Classes/Obj_trac_deepSort/DeepSort/deep_sort_pytorch/deep_sort/deep/

# %%
# !python train.py
# Out:
# Epoch : 1
# Testing ...
# [progress:100.0%]time:0.22s Loss:0.00000 Correct:22/22 Acc:100.000%
# Saving parameters to checkpoint/ckpt.t7
#
# Epoch : 2
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 3
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 4
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 5
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 6
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 7
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 8
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 9
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 10
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 11
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 12
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 13
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 14
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 15
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 16
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 17
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 18
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 19
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 20
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
# Learning rate adjusted to 0.010000000000000002
#
# Epoch : 21
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 22
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 23
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 24
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 25
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 26
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 27
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 28
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 29
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 30
# Testing ...
# [progress:100.0%]time:0.09s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 31
# Testing ...
# [progress:100.0%]time:0.08s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 32
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 33
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 34
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 35
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 36
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 37
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 38
# Testing ...
# [progress:100.0%]time:0.08s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 39
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 40
# Testing ...
# [progress:100.0%]time:0.06s Loss:0.00000 Correct:22/22 Acc:100.000%
# Learning rate adjusted to 0.0010000000000000002
